# %% [markdown]
# ### Python Mini-Project: Data Clean-Up, Pt. 2

# %%
# Dependencies
import pandas as pd

# %%
# load CSV
df = pd.read_csv("Resources/2016-FCC-New-Coders-Survey-Data.csv")
df.head()
# Out:
# C:\Users\dinom\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (21,57) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# ...

# %%
# Read with pandas--low_memory required to suppress errors about mixed data types

# %%
# Take only columns 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111

columns = [0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]
extract_df = df.iloc[ : , columns]
extract_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo BootcampName  BootcampPostSalary  BootcampRecommend  \
# 0                NaN          NaN                 NaN                NaN
# 1                NaN          NaN                 NaN                NaN
# 2                NaN          NaN                 NaN                NaN
# 3                NaN          NaN                 NaN                NaN
# 4                NaN          NaN                 NaN                NaN
#
#    ChildrenNumber                 CityPopulation  ...  \
# 0             NaN  between 100,000 and 1 million  ...
# ...

# %%
# Change reading 0 and 1 to No and Yes, respectively

extract_df= extract_df.replace({0.0 : 'no', 1.0: 'yes'})

extract_df.head()
# Out:
#     Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0  28.0               no            NaN                  NaN
# 1  22.0               no            NaN                  NaN
# 2  19.0               no            NaN                  NaN
# 3  26.0               no            NaN                  NaN
# 4  20.0               no            NaN                  NaN
#
#   BootcampLoanYesNo BootcampName  BootcampPostSalary BootcampRecommend  \
# 0               NaN          NaN                 NaN               NaN
# 1               NaN          NaN                 NaN               NaN
# 2               NaN          NaN                 NaN               NaN
# 3               NaN          NaN                 NaN               NaN
# 4               NaN          NaN                 NaN               NaN
#
#   ChildrenNumber                 CityPopulation  ...  \
# 0            NaN  between 100,000 and 1 million  ...
# 1            NaN  between 100,000 and 1 million  ...
# ...

# %%
# Extract rows for only those who attended a bootcamp

attendees_df = extract_df.loc[extract_df["AttendedBootcamp"] == "yes"]

attendees_df.head()
# Out:
#       Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93   32.0              yes            yes                   no
# 97   26.0              yes            yes                  yes
# 130  41.0              yes            yes                  yes
# 159  26.0              yes            yes                   no
# 188  24.0              yes             no                  NaN
#
#     BootcampLoanYesNo      BootcampName  BootcampPostSalary BootcampRecommend  \
# 93                 no    Codify Academy                 NaN                no
# 97                 no    DaVinci Coders             45000.0                no
# 130               yes     Coder Foundry             75000.0               yes
# 159                no  General Assembly                 NaN                no
# 188               yes               NaN                 NaN                no
#
#     ChildrenNumber                 CityPopulation  ...  \
# 93             NaN  between 100,000 and 1 million  ...
# ...

# %%
# Create DataFrame of the different boot camps that had a significant number of attendees

bootcamp = attendees_df.groupby(["BootcampName"])

bootcamp_attendees = bootcamp["AttendedBootcamp"].count()

bootcampA_df= pd.DataFrame(bootcamp_attendees)

bootcampA_df = bootcamp_df.sort_values("AttendedBootcamp", ascending=False)

bootcampA_df = bootcampA_df.reset_index()

# %%
# Count how many attendees of each bootcamp would recommend the bootcamp

recommend_df = attendees_df.loc[extract_df["BootcampRecommend"] == "yes"]

recommend = recommend_df.groupby(["BootcampName"])

bootcamp_recommend = recommend["BootcampRecommend"].count()

bootcampB_df= pd.DataFrame(bootcamp_recommend)

bootcampB_df = bootcampB_df.sort_values("BootcampRecommend", ascending=False)

bootcampB_df = bootcampB_df.reset_index()

# %%
# Merge the two created data frames on the name of tbe bootcamp

merge_df = pd.merge(bootcampA_df, bootcampB_df, on = "BootcampName")

merge_df.head()
# Out:
#             BootcampName  AttendedBootcamp  BootcampRecommend
# 0       General Assembly                90                 70
# 1        Flatiron School                54                 50
# 2           Dev Bootcamp                48                 41
# 3          The Iron Yard                40                 31
# 4  Prime Digital Academy                30                 25

# %%
# Calculate percentage of eac bootcamp's students who are recommenders

merge_df["% Recommend"] = round(merge_df['BootcampRecommend'] / merge_df['AttendedBootcamp'] *100 , 2)

merge_df = merge_df.sort_values("% Recommend", ascending=False)

merge_df = merge_df.rename(columns={"AttendedBootcamp":"Count", "BootcampRecommend":"Amount that Recommend"})
merge_df["% Recommend"] = merge_df["% Recommend"].map("{:.2f}%".format)

merge_df
# Out:
#                                 BootcampName  Count  Amount that Recommend  \
# 58                      Grace Hopper Academy      3                      3
# 47                        Academia de Código      4                      4
# 92                                  Le Wagon      1                      1
# 91  Launch School (formerly Tealeaf Academy)      1                      1
# 90                      Ladies Learning Code      1                      1
# ..                                       ...    ...                    ...
# 64                            We Can Code IT      3                      1
# 57                                tradecraft      3                      1
# 55                              Coding House      3                      1
# 67                            Starter League      3                      1
# 46                            Codify Academy      4                      1
#
#    % Recommend
# 58     100.00%
# 47     100.00%
# 92     100.00%
# ...

# %%
# Export to excel and remove index
merge_df.to_excel("Output/summary.xlsx", index=False, header=True)
